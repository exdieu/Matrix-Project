# %% [markdown]
# <a href="https://colab.research.google.com/github/exdieu/Matrix-Project/blob/main/integrating_pill_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import random

### ACTIONS ###
def you_died(why):
    print_game_over()
    # You expect a reason why the player died. It's a string.
    print("{}. Good job!".format(why))

    # This exits the program entirely.
    exit(0)

### END ACTIONS ###

### MATRIX ADVENTURE ###
def start_matrix_adventure():
    print("A man in black holds three pills; each has a unique color. They are red, blue and green.")
    pill_picked= input("Choose the color of one of the pills to decide your destiny > ")
    if pill_picked.lower() in ["red"]: #checks if user typed “red”
        red_pill() #runs red_pill function 
    elif pill_picked.lower() in ["blue"]: #checks if user typed “blue”
        blue_pill() #runs blue_pill function 
    elif pill_picked.lower() in ["green"]: #checks if user typed “green”
        green_pill() #runs green_pill function 
    else:
        #if user typed anything other than red,blue, or green, they are presented with a sentence ending the program 
        print("Sorry it is either 'red' 'blue' or 'green' as the answer. Very well then. Goodbye")
 
def main():
    ##Gets the players name, print it out and starts the adventure
    ##If the user typed nothing, it prints, "Ok anyway..." and starts the adventure
    player_name =  input("What's your name? > ")
    if player_name and not player_name.isspace():
        print(f"Ok {player_name.capitalize()}")
    else:
        print("Ok anyway...")
    start_matrix_adventure()

### RED PILL ###
def red_pill():
    # You are being tested by matrix
    print("You eat the red pill and are told 'You must believe'.")
    print("Suddenly, the world around you warps and you teleport on top of a tower.")
    print("You are told to run and jump across to another building that is very far as a test.")
    while True:
        task_decision = input("Will you make the leap or run away? >\n")
        # If you choose leap you jump and die
        # Choosing run away sends you back to the start of red pill
        # If nothing typed or made a mistake repeat the function
        if task_decision == "leap":
            print("You sprint towards the edge with the words 'you must believe' in your mind and leap.")
            print("Suspended in the air in between the two buildings you begin to decend.")
            print("YOU DIDN'T BELIEVE HARD ENOUGH")
            computer_art()
            print("~ Game Over ~")
            exit()
            break
        elif task_decision == "run away":
            print("You try to run away but you keep warping back to the top of the building.")
        else:
            print("Unknown response, please try again")

### BLUE PILL ###
def blue_pill():
    # The world of birds welcomes you
    print("You swallow the blue pill.")
    print("You get transferred into a world full of birds.")
    print("Two budgies swarm around you in curiosity.")
    print("The green budgie asks you to follow them into a dungeon as they can lead you to great treasures.")
    print("The white budgie asks you to follow them into a forest where you will be met with a banquet.")
    next_move = (input(print("Who do you go with, the green or white budgie?  green or white?"))).lower()
    # Selecting green budgie will begin an adventure with traps along the way
    # Selecting white budgie is poisonous
    # If left blank or made a mistake, you die of starvation
    if next_move in ["green"]:
        print("And so you choose green. The green budgie was glad you choose them.")
        print("As you both enter the dungeon, you were faced with multiple traps.")	
        print("")
    elif next_move in ["white"]:
        print("You choose to go with the white budgie")
        print("You were skeptical of the idea of following a bird into an unknown forest but here you are.")
        print("Following the budgie into the forest, are you were met with a delicious banquet.")
        print("You relax and enjoy the food and abruptly fall asleep.")
        print("poison.")
        print("And that was the end of you...")
        print("Game over")
    else:
        print("Days go by. No response from you.")
        print("The budgies became impatient and left you on your own in this world.")
        print("You eventually die out of starvation and become one with the world.")

### GREEN PILL ###
def green_pill():  
    print_matrix()
    # In a void, the phone is ringing
    print(".........................................................................")
    print('''\nLet me tell you why you’re here. You are here because you know something.
          What you know, you can’t explain. But you feel it.\n''')
    print("RIIIIIING... RIIIIIING... RIIIIIING... RIIIIIING... RIIIIIING... RIING...")
    action = input("\nThe phone is ringing. What do you do? [answer | ignore] > ").lower()
    print("\n...............................................................")

    # If you answer, you proceed to the sensei dojo
    # If you ignore it, that was all a dream to you "back to matrix"
    # If you make a mistake, it won't kill you "mistakes happen"
    if action in ['answer']:
        chosen_one_sensei_dojo()
    elif action in ['ignore']:
        print("\nI have dreamed a dream, but now that dream is gone from me...")
        start_matrix_adventure()
    else:
        print("\nNot sure what you meant there... try again.")
        green_pill()
 
def chosen_one_sensei_dojo():
    print_sensei()
    # Lessons at the dojo
    print('''\n\tDo you believe in fate?
    \n\tHere is what will happen
    \n\tYou will have three choices
    \n\tIf you pick the right one
    \n\tYou will survive
    \n\tIf you pick incorrect you will...\n''')
    # Sensei and you select a choice
    sensei_choice = random.choice(['green', 'red', 'blue'])
    user_choice = input('... What color do you choose? [blue | red | green] > ').lower()
    print("\n...............................................................")

    # If sensei chose the same color as you, you go back to the matrix adventure
    # If you win, you take the blue pill
    # If you left a blank, you end up in hell
    # If you lose or make a mistake, you take the red pill
    if sensei_choice in user_choice:
        print('\nYou got away with it!')
        start_matrix_adventure()
    elif user_choice in ['green'] and sensei_choice in ['blue']:
        print('\nYou are the chosen one! You can proceed')
        blue_pill()
    elif user_choice in ['red'] and sensei_choice in ['green']:
        print('\nGood choice! You can proceed')
        blue_pill()
    elif user_choice in ['blue'] and sensei_choice in ['red']:
        print('\nBlue?! ... You can proceed')
        blue_pill()
    elif user_choice in ['']:
        print_death()
        print('... THE HELL RAINS FIRE UPON YOU!')
        you_died("Got burned, huh")
    else:
        print('\nBest luck next time! :D\n')
        red_pill()

### END PILLS ###
 
### ART IDEAS ###
def print_dungeon(): 
    print()
    print("   _________________________________________________________")
    print(" /|     -_-                                             _-  |\ ")
    print("/ |_-_- _                                         -_- _-   -| \   ")
    print("  |                            _-  _--                      | ")
    print("  |                            ,                            |")
    print("  |      .-'````````'.        '(`        .-'```````'-.      |")
    print("  |    .` |           `.      `)'      .` |           `.    |          ")
    print("  |   /   |   ()        \      U      /   |    ()       \   |")
    print("  |  |    |    ;         | o   T   o |    |    ;         |  |")
    print("  |  |    |     ;        |  .  |  .  |    |    ;         |  |")
    print("  |  |    |     ;        |   . | .   |    |    ;         |  |")
    print("  |  |    |     ;        |    .|.    |    |    ;         |  |")
    print("  |  |    |____;_________|     |     |    |____;_________|  |  ")
    print("  |  |   /  __ ;   -     |     !     |   /     `'() _ -  |  |")
    print("  |  |  / __  ()        -|        -  |  /  __--      -   |  |")
    print("  |  | /        __-- _   |   _- _ -  | /        __--_    |  |")
    print("  |__|/__________________|___________|/__________________|__|")
    print(" /                                             _ -        lc \ ")
    print("/   -_- _ -             _- _---                       -_-  -_ \ ")
    print()
 
def computer_art():
    print("░░░░░░░░░▒▒▒▒░░░█░░░░░░░░░░░░░░░░░░░░░░░")
    print("░░░░░▒▒▒█▒▒░░░░░█░░░░▒▒▒▒▒▒░░░░░░░░░░░░░")
    print("░░░░░░░░█░░░░░░░█░░░▒▒▒▒▒░█▒▒▒▒▒▒░░░░░░░")
    print("░░░░░░░░█░░░░░░░░░░░░░░░░░█░░░░░░░░░░░░░")
    print("░░░░░░░░█░░░░░░░░░░▐█▄░░░░░░░░░░░░░░░▒▒░")
    print("░░░░░░░░░░░░░░░░░░░▐██░░░█▌░░░░░░░▒▒▒▒▒░")
    print("░░▒▒▒▒░░░░░░░░█▌░▐▌░▐█░░░█▌░░░░░░▒▒▒▒▒▒▒")
    print("░░░░░▒▒▒▒▒▒░░░█▌░█▌░██░███▌░░░░░░░▒▒▒▒▒░")
    print("░░░▒▒▒▒▒▒░░░░░██▐█░▐█████▀░░░░░░░░░░░░░░")
    print("░░░░▒▒▒▒░░▄▄▄▄████▄█████░░░░░░░░░░░░░░░░")
    print("░░░░░░░░░██████████████░░░░░░▒▒▒▒▒░░░░░░")
    print("░░░░░░░░▐█████████████░░░░░░░░░░▒▒▒▒▒▒▒░")
    print("░░░░░░░░▐███████████▀░░░░░░░░░░░░░░░░░░░")
    print("░░░░░░░░░▀█████▀░░░░░░░▒▒▒▒░░░░░░░░░░░░░")
    print("░░░▒▒▒▒░░░░░░░░░░░░░░░░░░▒▒▒░░░░░░░░░░░░")
    print("░░░░░▒▒▒▒▒▒░░░░░░░░░▒▒▒▒▒▒░░▒░░░░░░░░░░░")
    print("░░▒▒▒▒▒░░░▒░░░░░░░░░░░░░░░░░░░░░░░░░░░░░")
    print("░░░░░░░░░░█░░░█░░█░█░░█░░█░█░░░░░░░░░░░░")
    print("░░░░░░░░░█░█░░████░████░░█░█░░░░░░░░░░░░")
    print("░░░░░░░░░███░░█░░█░█░░█░░░░░░░░░░░░░░░░░")
    print("░░░░░░░░█░░░█░█░░█░█░░█░░█░█░░░░░░░░░░░░")
    print("░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░")
    print("░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░")

def print_monster():
    print()
    print("                           |                     | ")
    print("                        \     /               \     / ")
    print("                       -= .'> =-             -= <'. =- ")
    print("                          '.'.                 .'.' ")
    print("                            '.'.             .'.' ")
    print("                              '.'.----^----.'.' ")
    print("                               /'==========='\ ")
    print("                           .  /  .-.     .-.  \  . ")
    print("                           :'.\ '.O.') ('.O.' /.':   ")
    print("                           '. |               | .'   ")
    print("                             '|      / \      |' ")
    print("                              \     (o'o)     / ")
    print("                              |\             /| ")
    print("                              \('._________.')/ ")
    print("                               '. \/|_|_|\/ .'                ")
    print("                                /'._______.'\ lc ")
    print()

def print_chest():
    print()
    print("                      _.--. ")
    print("                  _.-'_:-'|| ")
    print("              _.-'_.-::::'|| ")
    print("         _.-:'_.-::::::'  || ")
    print("       .'`-.-:::::::'     || ")
    print("      /.'`;|:::::::'      ||_ ")
    print("     ||   ||::::::'     _.;._'-._ ")
    print("     ||   ||:::::'  _.-!oo @.!-._'-. ")
    print("     ('.  ||:::::.-!()oo @!()@.-'_.| ")
    print("      '.'-;|:.-'.&$@.& ()$%-'o.'-U|| ")
    print("        `>'-.!@%()@'@_%-'_.-o _.|'|| ")
    print("         ||-._'-.@.-'_.-' _.-o  |'|| ")
    print("         ||=[ '-._.-+U/.-'    o |'|| ")
    print("         || '-.]=|| |'|      o  |'|| ")
    print("         ||      || |'|        _| '; ")
    print("         ||      || |'|    _.-'_.-' ")
    print("         |'-._   || |'|_.-'_.-' ")
    print("          '-._'-.|| |' `_.-' ")
    print("              '-.||_/.-' ")
    print()

def print_guard():
    print()
    print("                                                  ___I___ ")
    print("                                                 /=  |  #\ ")
    print("                                                /.__-| __ \ ")
    print("                                                |/ _\_/_ \| ")
    print("                                                (( __ \__)) ")
    print("                                             __ ((()))))()) __ ")
    print("                                           ,'  |()))))(((()|# `. ")
    print("                                          /    |^))()))))(^|   =\ ")
    print("                                         /    /^v^(())()()v^;'  .\ ")
    print("                                         |__.'^v^v^))))))^v^v`.__| ")
    print("                                        /_ ' \______(()_____(   | ")
    print("                                   _..-'   _//_____[xxx]_____\.-| ")
    print("                                  /,_#\.=-' /v^v^v^v^v^v^v^v^| _| ")
    print("                                  \)|)      v^v^v^v^v^v^v^v^v| _| ")
    print("                                   ||       :v^v^v^v^v^v`.-' |#  \, ")
    print("                                   ||       v^v^v^v`_/\__,--.|\_=_/ ")
    print("                                   ><       :v^v____|  \_____|_ ")
    print("                                ,  ||       v^      /  \       / ")
    print("                               //\_||_)\    `/_..-._\   )_...__\ ")
    print("                              ||   \/  #|     |_='_(     |  =_(_ ")
    print("                              ||  _/\_  |    /     =\    /  '  =\ ")
    print("                               \\\/ \/ )/ gnv |=____#|    '=....#| ")
    print()

def print_matrix():
    print()
    print("                       ___________")
    print("                    /.---------.\`-._")
    print("                   //          ||    `-._")
    print("                   || `-._     ||        `-._")
    print("                   ||     `-._ ||            `-._")
    print("                   ||    _____ ||`-._            \ ")
    print("             _..._ ||   | __ ! ||    `-._        |")
    print("           _/     \||   .'  |~~||        `-._    |")
    print("       .-``     _.`||  /   _|~~||    .----.  `-._|")
    print("      |      _.`  _||  |  |23| ||   / :::: \    \ ")
    print("      \ _.--`  _.` ||  |  |56| ||  / ::::: |    |")
    print("       |   _.-`  _.||  |  |79| ||  |   _..-'   /")
    print("       _\-`   _.`O ||  |  |_   ||  |::|        |")
    print("     .`    _.`O `._||  \    |  ||  |::|        |")
    print("  .-`   _.` `._.'  ||   '.__|--||  |::|        \ ")
    print(" `-._.-` \`-._     ||   |  :  !||  |  '-.._    |")
    print('          \   `--._||   |_:"___||  | ::::: |   |')
    print('           \  /\   ||     ":":"||   \ :::: |   |')
    print("            \(  `-.||       .- ||    `.___/    /")
    print("            |    | ||   _.-    ||              |")
    print("            |    / \\.-________\\____.....-----'")
    print("            \    -.      \ |         |")
    print("             \     `.     \ \        | ")
    print("  __________  `.    .'\    \|        |\  _________")
    print("                `..'   \    |        | \ ")         
    print("                 \\   .'    |       /  .`.")
    print("                 | \.'      |       |.'   `-._")
    print("                  \     _ . /       \_\-._____)")
    print("                   \_.-`  .`'._____.'`.")
    print("                     \_\-|             |")
    print("                          `._________.' ")  
    print()

def print_death():
    print()     
    print("                       _.--.    .--._")
    print('                 ."  ."      ".  ".')
    print('                ;  ."    /\    ".  ;')
    print("                ;  '._,-/  \-,_.`  ;")
    print("                \  ,`  / /\ \  `,  /")
    print("                 \/    \/  \/    \/")
    print("                 ,=_    \/\/    _=,")
    print('                 |  "_   \/   _"  |')
    print('                 |_   '"-..-"'   _|')
    print('                 | "-.        .-" |')
    print('                 |    "\    /"    |')
    print("                 |      |  |      |")
    print("         ___     |      |  |      |     ___")
    print('     _,-\,  \,   |_     |  |     _|   ,/  ,/-,_')
    print('   _(  \  \   \ =----.  |  |  .----=/   /  /  )_')
    print(',"  \  \  \   \      "- -- -"      /   /  /  /  ".')
    print("!     \  \  \   \                  /   /  /  /     !")
    print(":      \  \  \   \                /   /  /  /")      
    print()

def print_sensei():
    print()     
    print("                    ____")
    print("                 _.' :  `._")
    print("             .-.'`.  ;   .'`.-.")
    print("    __      / : ___\ ;  /___ ; \ __")
    print("  ,'_ ""--.:__;'.-.';: :'.-.':__;.--"" _`,")
    print("  :' `.t""--.. '<@.`;_  ',@>` ..--""j.' `;")
    print("       `:-.._J '-.-'L__ `-- ' L_..-;'")
    print('         "-.__ ;  .-"  "-.  : __.-"')
    print("             L ' /.------.\ ' J")
    print('              "-.   "--"   .-"')
    print('             __.l"-:____;-";.__')
    print("          .-j/'.;  ;""''  / .'\"-.")
    print("        .' /:`. '-.:     .-' .';  `.")
    print("     .-'  / ;  '-. '-..-' .-'  :    '-.")
    print("  .+'-.  : :      '-.__.-'      ;-._   \ ")
    print("  ; \  `.; ;                    : : '+. ;")
    print("  :  ;   ; ;                    : ;  : \:")
    print(" : `.'-; ;  ;                  :  ;   ,/;")
    print("  ;    -: ;  :                ;  : .-''  :")
    print("  :\     \  : ;             : \.-'      :")
    print("   ;`.    \  ; :            ;.'_..--  / ;")
    print("   :  '-.  '-:  ;          :/.'      .'  :")
    print("     \       .-`.\        /'-""  ':-+.   :")
    print("      `.  .-'    `l    __/ /`. :  ; ; \  ;")
    print("        \   .-' .-'-.-'  .' .'j \  /   ;/")
    print("         \ / .-'   /.     .'.' ;_:'    ;")
    print("          :-""-.`./-.'     /    `.___.'")
    print("                \ `''  ._  / ")
    print("                 '-.t-._:'")
    print()

def print_game_over():
    print()
    print("   _____          __  __ ______    ______      ________ _____  ")
    print("  / ____|   /\   |  \/  |  ____|  / __ \ \    / /  ____|  __ \ ")
    print(" | |  __   /  \  | \  / | |__    | |  | \ \  / /| |__  | |__) |")
    print(" | | |_ | / /\ \ | |\/| |  __|   | |  | |\ \/ / |  __| |  _  / ")
    print(" | |__| |/ ____ \| |  | | |____  | |__| | \  /  | |____| | \ \ ")
    print("  \_____/_/    \_\_|  |_|______|  \____/   \/   |______|_|  \_\\")
    print()

### END ART IDEAS ###

### MAIN FUNCTION ###
if __name__ == '__main__':
    main()
